# %% [markdown]
# # Persamaan Linier

# %% [markdown]
# # 1. Apa itu Persamaan Linier
# Persamaan linear adalah persamaan aljabar di mana setiap suku memiliki pangkat 1 dan jika persamaan ini digrafikkan maka hasilnya selalu berupa garis lurus.

# %% [markdown]
# # 2. Contoh Persamaan Linier dengan dua variabel
# $$ 4x + 3y=32 $$
#
# $$ 6x + 2y + 9= 0 $$

# %% [markdown]
# # 3. Gambar dua Persamaan Linier
#
# ![image.png](attachment:image.png)

# %%
from IPython.display import IFrame

IFrame("https://www.geogebra.org/classic", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="https://www.geogebra.org/classic"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
